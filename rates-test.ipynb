# %%
import numpy as np
import pandas as pd

import pandas_datareader.data as web

from sktime.forecasting.var import VAR
from sktime.utils.plotting import plot_series

from Subspace import StateSpaceModel

# настройки визуализация
import matplotlib.pyplot as plt

# Не показывать Warnings
import warnings
warnings.simplefilter(action='ignore', category=Warning)
# Не показывать ValueWarning из statsmodels
from statsmodels.tools.sm_exceptions import ValueWarning
warnings.simplefilter('ignore', category=ValueWarning)

# %%
rates = web.DataReader(name=['TB3MS', 'GS10', 'AAA', 'BAA'], data_source='fred',start='1990-01', end='2023-12')

# %%
plot_series(rates.iloc[:,0], rates.iloc[:,1], rates.iloc[:,2], rates.iloc[:,3], markers=['.', '.', '.', '.'])
# Out:
# (<Figure size 1600x400 with 1 Axes>, <Axes: ylabel='TB3MS'>)

# %%
ssm = StateSpaceModel(5)

# %%
ssm.fit(rates)

# %%
ssm.predict(10)
# Out:
# array([[3.2761204 , 2.68792602, 3.56350698, 4.29955107],
#        [3.32374515, 2.69762022, 3.55788658, 4.2920653 ],
#        [3.36893453, 2.70597442, 3.55115923, 4.28331739],
#        [3.41161277, 2.71296433, 3.54331659, 4.27328777],
#        [3.45170959, 2.71856996, 3.53435402, 4.26196139],
#        [3.48916037, 2.72277565, 3.52427054, 4.24932776],
#        [3.52390636, 2.72557017, 3.51306893, 4.23538098],
#        [3.55589482, 2.72694667, 3.50075562, 4.22011979],
#        [3.58507918, 2.72690274, 3.48734076, 4.2035476 ],
#        [3.61141917, 2.7254404 , 3.47283809, 4.18567246]])
